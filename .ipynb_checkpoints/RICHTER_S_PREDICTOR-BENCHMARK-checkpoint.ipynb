# %%
# %matplotlib inline

from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns


from keras.models import Sequential 
from keras.layers import Dense 
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical
from sklearn.utils import shuffle
# Out:
# Using TensorFlow backend.

# %%
DATA_DIR = Path('.', 'data', 'final', 'public')

# %%
train_values = pd.read_csv(DATA_DIR / 'train_values.csv', index_col='building_id')
train_labels = pd.read_csv(DATA_DIR / 'train_labels.csv', index_col='building_id')

# %%
train_values.dtypes
# Out:
# geo_level_1_id                             int64
# geo_level_2_id                             int64
# geo_level_3_id                             int64
# count_floors_pre_eq                        int64
# age                                        int64
# area_percentage                            int64
# height_percentage                          int64
# land_surface_condition                    object
# foundation_type                           object
# roof_type                                 object
# ground_floor_type                         object
# other_floor_type                          object
# position                                  object
# plan_configuration                        object
# has_superstructure_adobe_mud               int64
# has_superstructure_mud_mortar_stone        int64
# has_superstructure_stone_flag              int64
# has_superstructure_cement_mortar_stone     int64
# has_superstructure_mud_mortar_brick        int64
# ...

# %%
train_labels.damage_grade.value_counts().sort_index().plot.bar(title="Number of Buildings with Each Damage Grade")

# %%
selected_features = ['foundation_type', 
                     'area_percentage', 
                     'height_percentage',
                     'count_floors_pre_eq',
                     'land_surface_condition',
                     'has_superstructure_cement_mortar_stone']

train_values_subset = train_values[selected_features]

# %%
test_values = pd.read_csv(DATA_DIR / 'test_values.csv', index_col='building_id')

# %%
train_values_subset.head(20)
# Out:
#             foundation_type  area_percentage  height_percentage  \
# building_id
# 802906                    r                6                  5
# 28830                     r                8                  7
# 94947                     r                5                  5
# 590882                    r                6                  5
# 201944                    r                8                  9
# 333020                    r                9                  5
# 728451                    r                3                  4
# 475515                    w                8                  6
# 441126                    r                8                  6
# 989500                    i               13                  4
# 7962                      r                9                  6
# 452227                    u                8                  4
# 444381                    r                6                  5
# ...

# %%
foundation_type=train_values_subset['foundation_type']
encoder = LabelEncoder()
encoder.fit(foundation_type)
foundation_type_Y = encoder.transform(foundation_type)
foundation_type_label=encoder.classes_
foundation_type_label=["foundation_type_"+s for s in foundation_type_label]
foundation_type_Y = np_utils.to_categorical(foundation_type_Y)
train_values_subset_n=pd.concat([train_values_subset,pd.DataFrame(data=foundation_type_Y,columns=foundation_type_label,index=train_values_subset.index)],axis=1)
foundation_type.shape,len(foundation_type_label),foundation_type_Y.shape,train_values_subset.shape
del(train_values_subset_n["foundation_type"])
del(foundation_type_Y)
train_values_subset_n.head()
# Out:
#              area_percentage  height_percentage  count_floors_pre_eq  \
# building_id
# 802906                     6                  5                    2
# 28830                      8                  7                    2
# 94947                      5                  5                    2
# 590882                     6                  5                    2
# 201944                     8                  9                    3
#
#             land_surface_condition  has_superstructure_cement_mortar_stone  \
# building_id
# 802906                           t                                       0
# 28830                            o                                       0
# 94947                            t                                       0
# 590882                           t                                       0
# 201944                           t                                       0
#
#              foundation_type_h  foundation_type_i  foundation_type_r  \
# ...

# %%
land_surface_condition=train_values_subset['land_surface_condition']
encoder.fit(land_surface_condition)
land_surface_condition_Y = encoder.transform(land_surface_condition)
land_surface_condition_label=encoder.classes_
land_surface_condition_Y = np_utils.to_categorical(land_surface_condition_Y)
land_surface_condition_label

# %%
del(train_values_subset_1)
