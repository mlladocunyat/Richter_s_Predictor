# %%
# %matplotlib inline

from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import math

from keras.models import Sequential 
from keras.layers import Dense 
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical
from sklearn.utils import shuffle
# Out:
# Using TensorFlow backend.

# %%
DATA_DIR = Path('.', 'data', 'final', 'public')

# %%
train_values = pd.read_csv(DATA_DIR / 'train_values.csv', index_col='building_id')
train_labels = pd.read_csv(DATA_DIR / 'train_labels.csv', index_col='building_id')

# %%
#print(train_values.dtypes)
s = (train_values.dtypes == 'object')
object_cols = list(s[s].index)
s = (train_values.dtypes != 'object')
number_cols = list(s[s].index)

# %%
test_values = pd.read_csv(DATA_DIR / 'test_values.csv', index_col='building_id')

# %%
sns_data=train_values[number_cols].copy()

# %%
for col in sns_data.columns:
    sns.distplot(sns_data[col],kde = False)

# %%
fig = plt.figure(figsize=(80, 500))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, len(sns_data.columns)+1):
    ax = fig.add_subplot(15,2, i,label=sns_data.columns[i-1])
    ax.hist(x=sns_data[sns_data.columns[i-1]], bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)

# %%
train_values.describe()
# Out:
#        geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  \
# count   260601.000000   260601.000000   260601.000000        260601.000000
# mean        13.900353      701.074685     6257.876148             2.129723
# std          8.033617      412.710734     3646.369645             0.727665
# min          0.000000        0.000000        0.000000             1.000000
# 25%          7.000000      350.000000     3073.000000             2.000000
# 50%         12.000000      702.000000     6270.000000             2.000000
# 75%         21.000000     1050.000000     9412.000000             2.000000
# max         30.000000     1427.000000    12567.000000             9.000000
#
#                  age  area_percentage  height_percentage  \
# count  260601.000000    260601.000000      260601.000000
# mean       26.535029         8.018051           5.434365
# std        73.565937         4.392231           1.918418
# min         0.000000         1.000000           2.000000
# ...

# %%
sns.distplot(sns_data['area_percentage'],kde = False)

# %%
sns_data[sns_data['area_percentage']>80]['area_percentage'].count()
# Out:
# 21
